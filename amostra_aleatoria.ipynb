# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('clustering/Data.csv').rename(columns = {'Unnamed: 0': 'index'})
data['index'] = data['index'] + 1

# %%
data.shape
# Out:
# (8068, 10)

# %%
data.head()
# Out:
#    index      ID  Gender Ever_Married  Age Graduated     Profession
# 0      1  462809    Male           No   22        No     Healthcare  \
# 1      2  462643  Female          Yes   38       Yes       Engineer
# 2      3  466315  Female          Yes   67       Yes       Engineer
# 3      4  461735    Male          Yes   67       Yes         Lawyer
# 4      5  462669  Female          Yes   40       Yes  Entertainment
#
#    Work_Experience Spending_Score  Family_Size  Var_1
# 0              1.0            Low          4.0  Cat_4
# 1              NaN        Average          3.0  Cat_4
# 2              1.0            Low          1.0  Cat_6
# 3              0.0           High          2.0  Cat_6
# 4              NaN           High          6.0  Cat_6

# %%
np.random.seed(101)
amostra_aleatoria = np.random.randint(len(data), size = 300).tolist()
amostra_aleatoria = sorted(amostra_aleatoria)
max(amostra_aleatoria)
# Out:
# 8063

# %%
amostra_aleatoria
# Out:
# [22,
#  40,
#  49,
#  75,
#  97,
#  144,
#  190,
#  208,
#  239,
#  343,
#  357,
#  359,
#  394,
#  436,
#  451,
#  554,
#  561,
#  591,
#  599,
#  609,
#  632,
#  711,
#  788,
#  811,
#  813,
#  855,
#  906,
#  907,
#  908,
#  947,
#  973,
#  1015,
#  1021,
#  1076,
#  1118,
#  1232,
#  1268,
#  1273,
#  1278,
#  1300,
#  1309,
#  1327,
#  1351,
#  1361,
#  1393,
#  1401,
#  1426,
#  1436,
#  1446,
#  1485,
#  1487,
#  1512,
#  1523,
#  1527,
#  1530,
#  1547,
#  1561,
#  1580,
#  1582,
#  1594,
#  1667,
#  1699,
#  1709,
#  1716,
#  1818,
#  1878,
#  1885,
#  1898,
#  1937,
#  1944,
#  1949,
#  1967,
#  1980,
#  1992,
#  2021,
#  2053,
#  2059,
#  2100,
#  2107,
#  2115,
#  2119,
#  2136,
#  2158,
#  2184,
#  2251,
#  2262,
#  2265,
#  2274,
#  2292,
#  2318,
#  2321,
#  2323,
#  2353,
#  2404,
#  2426,
#  2467,
#  2532,
#  2535,
#  2546,
#  2553,
#  2583,
#  2614,
#  2623,
#  2637,
#  2706,
#  2751,
#  2757,
#  2789,
#  2863,
#  2931,
#  2932,
#  2939,
#  2943,
#  2959,
#  2971,
# ...

# %%
data_filtrada = data[data['index'].isin(amostra_aleatoria)]
data_filtrada
# Out:
#       index      ID  Gender Ever_Married  Age Graduated     Profession
# 21       22  459675  Female           No   18        No     Healthcare  \
# 39       40  467442    Male          Yes   56       Yes         Artist
# 48       49  462442    Male           No   19        No     Healthcare
# 74       75  463742    Male          Yes   56       Yes         Artist
# 96       97  459976  Female           No   38       Yes         Artist
# ...     ...     ...     ...          ...  ...       ...            ...
# 7971   7972  466121  Female          Yes   57       Yes         Artist
# 7995   7996  460210    Male           No   29       NaN  Entertainment
# 8005   8006  464518    Male          Yes   30        No      Executive
# 8047   8048  462396    Male          Yes   50       Yes         Doctor
# 8062   8063  463002    Male          Yes   41       Yes         Artist
#
#       Work_Experience Spending_Score  Family_Size  Var_1
# 21                3.0            Low          4.0  Cat_6
# ...
